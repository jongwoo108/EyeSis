# %%
# 프로젝트 루트 디렉토리로 작업 디렉토리 설정
import os
import sys
from pathlib import Path

# notebooks 폴더에서 실행 중이면 상위 폴더로 이동
if Path.cwd().name == "notebooks":
    os.chdir("..")
    print(f"작업 디렉토리: {os.getcwd()}")

# %%
import numpy as np

emb = np.load("outputs/embeddings/hani.npy")
print(emb)
# Out:
# [ 1.60860829e-02  5.33861220e-02  5.24914116e-02  1.68222301e-02
#   1.80391073e-02 -8.06201026e-02  5.41074723e-02  1.82937998e-02
#   1.54370815e-02 -6.72819139e-03 -8.54970217e-02  5.58754168e-02
#  -9.19243991e-02 -1.87602229e-02 -7.21168295e-02 -3.43615599e-02
#  -1.42110707e-02 -5.16890809e-02 -2.44610570e-02  5.08350432e-02
#   4.67380770e-02 -5.76014146e-02  4.74140653e-03  1.06738351e-01
#  -3.55028287e-02 -1.81442648e-02  1.04919963e-01 -2.05149106e-03
#  -3.56511138e-02  3.87904514e-03  3.10180373e-02  1.17298113e-02
#  -1.23101724e-02 -5.28577939e-02  4.78711352e-02  3.92919742e-02
#  -7.97037631e-02 -3.68521437e-02 -6.24615420e-03  4.03574035e-02
#   5.90065261e-03  2.40894593e-02 -3.42386998e-02  4.17165905e-02
#  -5.79378046e-02 -3.23115923e-02  6.10275976e-02  1.04431706e-02
#   8.03568289e-02 -4.70137671e-02 -6.21164218e-02 -7.03081628e-03
#   2.38304362e-02  4.75837700e-02 -1.01489304e-02  1.08366594e-01
# ...

# %%
with open("outputs/embeddings/hani.npy", "rb") as f:
    data = np.lib.format.read_array(f)
    print(data.shape)
    print(data.dtype)
# Out:
# (512,)
# float32

# %%
import matplotlib.pyplot as plt

emb = np.load("outputs/embeddings/hani.npy")

plt.hist(emb, bins=50, color="blue", alpha=0.7)
plt.title("Embedding Value Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
import numpy as np

emb = np.load("outputs/embeddings/hani_bank.npy")
print(emb)
# Out:
# [[ 0.01608608  0.05338612  0.05249141 ...  0.05882416 -0.01683245
#   -0.06203825]
#  [-0.07488717 -0.03713035  0.03845682 ...  0.01040388  0.00231858
#    0.01065782]
#  [-0.01966521 -0.00059261  0.07497617 ...  0.02775999 -0.04040671
#   -0.00368347]
#  ...
#  [-0.05514977 -0.04339088  0.03965801 ... -0.01133021 -0.03317809
#    0.00251138]
#  [-0.05411839  0.00449225  0.02833858 ...  0.01758157 -0.00683113
#    0.00988092]
#  [-0.04101541  0.01113548  0.02962804 ...  0.03550677  0.04672477
#    0.01849145]]

# %%
emb.shape
# Out:
# (9, 512)
